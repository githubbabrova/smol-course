# %% [markdown]
# # Inference pipeline

# %%
from transformers import pipeline

# Create a pipeline with a specific model
generator = pipeline(
    "text-generation",
    model="HuggingFaceTB/SmolLM2-1.7B-Instruct",
    torch_dtype="auto",
    device_map="auto"
)

# Generate text
response = generator(
    "Write a short poem about coding:",
    max_new_tokens=100,
    do_sample=True,
    temperature=0.7
)
print(response[0]['generated_text'])
# Out:
# Some parameters are on the meta device because they were offloaded to the cpu.
# Write a short poem about coding:
#
# Code is art,
# Like a symphony,
# Like a dance,
# Like a work of art.
#
# Coding's a key,
# To unlock the code,
# To create and to see,
# A world of wonder.
#
# Coding's the way,
# To make the magic,
# To bring the code,
# To life.

# %%
# Prepare multiple prompts
prompts = [
    "Write a haiku about programming:",
    "Explain what an API is:",
    "Write a short story about a robot:"
]

# Process all prompts efficiently
responses = generator(
    prompts,
    batch_size=4,              # Number of prompts to process together
    max_new_tokens=100,
    do_sample=True,
    temperature=0.7
)

# Print results
for prompt, response in zip(prompts, responses):
    print(f"Prompt: {prompt}")
    print(f"Response: {response[0]['generated_text']}\n")
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Prompt: Write a haiku about programming:
# Response: Write a haiku about programming: about [hacker] [programming] [technology]
#
# Prompt: Explain what an API is:
# Response: Explain what an API is: is it a protocol, a library, a set of instructions, a rule, a standard, a software?
#
# Prompt: Write a short story about a robot:
# Response: Write a short story about a robot:
