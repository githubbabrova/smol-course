# %% [markdown]
# # Building AI Agents
#
# This notebook contains exercises to help you learn how to build different types of agents using the `smolagents` library. We'll progress from basic to more complex implementations.
#
# ## Setup
#
# First, let's install the required packages:

# %%
#!pip install smolagents

# Install the requirements in Google Colab
# !pip install transformers datasets trl huggingface_hub

# Authenticate to Hugging Face
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## 🐢 Exercise 1: Basic Code Agent
#
# Let's start by creating a simple code agent that can answer programming-related questions using web search.

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel

# Initialize the agent
agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=HfApiModel())

# Test the agent
response = agent.run("What's the difference between a list and a tuple in Python?")
print(response)
# Out:
# /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/models.py:1372: FutureWarning: HfApiModel was renamed to InferenceClientModel in version 1.14.0 and will be removed in 1.17.0.
#   warnings.warn(
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What's the difference between a list and a tuple in Python?                                                     │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   difference = web_search(query="difference between list and tuple in Python")
#   print("Difference between list and tuple:", difference)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Difference between list and tuple: ## Search Results
#
# [Difference Between List and Tuple in Python -
# GeeksforGeeks](https://www.geeksforgeeks.org/python-difference-between-list-and-tuple/)
# In Python, lists and tuples both store collections of data, but differ in mutability, performance and memory usage.
# Lists are mutable, allowing modifications, while tuples are immutable. Choosing between them depends on whether you
# need to modify the data or prioritize performance and memory efficiency. Key Differences between List and Tuple
#
# [Difference Between Lists and Tuples in Python - Online Tutorials
# Library](https://www.tutorialspoint.com/difference-between-list-and-tuples-in-python)
# Learn how to create, display and modify lists and tuples in Python, two built-in data types that store multiple
# values. Compare their mutability, iteration, memory consumption, methods and error prone properties.
#
# [python - What's the difference between lists and tuples ... - Stack
# ...](https://stackoverflow.com/questions/626759/whats-the-difference-between-lists-and-tuples)
# The PEP 484 -- Type Hints says that the types of elements of a tuple can be individually typed; so that you can say
# Tuple[str, int, float]; but a list, with List typing class can take only one type parameter: List[str], which hints
# that the difference of the 2 really is that the former is heterogeneous, whereas the latter intrinsically
# homogeneous.
#
# [Difference between Tuple and List in Python | Tuples vs Lists](https://pythongeeks.org/tuples-vs-lists/)
# Learn the difference between tuples and lists in Python, two sequence types of data structures. Tuples are
# immutable, ordered, and allow duplicate values, while lists are mutable, ordered, and allow duplicate values.
#
# [Difference Between List and Tuple in Python (with Comparison Chart
# ...](https://techdifferences.com/difference-between-list-and-tuple-in-python.html)
# Learn the key differences between list and tuple, two sequence data types in Python. Lists are mutable, dynamic and
# consume more memory, while tuples are immutable, fast and suitable for dictionary keys.
#
# [Difference Between List and Tuple in Python (With
# Example)](https://www.wscubetech.com/blog/difference-between-list-and-tuple-in-python/)
# Learn the key differences between list and tuple, two data structures in Python, based on mutability, syntax,
# operations, and use cases. See examples of how to create and manipulate lists and tuples in Python code.
#
# [Python Tuple vs List: The Differences Between Tuple and List in
# Python](https://www.pythontutorial.net/advanced-python/python-tuple-vs-list/)
# Learn how to use tuple and list in Python, two sequence types with different properties. Tuple is immutable,
# efficient, and fast to copy, while list is mutable, inefficient, and slow to copy.
#
# [Differences Between List and Tuple in Python -
# Simplilearn](https://www.simplilearn.com/difference-between-list-and-tuple-in-python-article)
# Learn the differences between list and tuple in Python, two sequence data types that store objects of any type.
# Lists are mutable and dynamic, while tuples are immutable and static, affecting their speed, memory usage, and
# methods.
#
# [Differences Between List, Tuple, Set, and Dictionary in
# Python](https://python.plainenglish.io/differences-between-list-tuple-set-and-dictionary-in-python-8ff01d1f370e)
# Difference Between List VS Tuple VS Set, VS Dictionary in Python Definition. List: A list is an ordered, mutable
# collection of elements. Tuple: A tuple is an ordered, immutable collection of elements. Set: A set is an unordered
# collection of unique elements. Dictionary: A dictionary is an unordered collection of key-value pairs. Syntax.
# List: Syntax includes square brackets [ , ] with ...
#
# [Understanding the Difference Between Lists and Tuples in
# Python](https://coderivers.org/blog/difference-between-lists-and-tuples-in-python/)
# Python is a versatile programming language known for its simplicity and readability. Two fundamental data
# structures in Python are lists and tuples. While they may seem similar at first glance, they have distinct
# characteristics that make them suitable for different use cases. In this blog post, we will explore the differences
# between lists and tuples in Python, their usage methods, common ...
#
# Out: None
# [Step 1: Duration 5.38 seconds| Input tokens: 2,050 | Output tokens: 85]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extracting and consolidating key differences
#   key_differences = """
#   Key Differences between Python List and Tuple:
#   1. **Mutability**: Lists are mutable (can be modified after creation), while tuples are immutable (cannot be
#   modified after creation).
#   2. **Performance**: Tuples can be slightly faster than lists due to their immutability.
#   3. **Memory Usage**: Tuples can use less memory compared to lists.
#   4. **Usage**: Lists are generally used for collections of homogeneous elements, while tuples can be used for
#   heterogeneous elements.
#   5. **Methods**: Lists have more built-in methods that allow modifications like append(), remove(), insert(),
#   etc., whereas tuples have fewer methods (count(), index()).
#   """
#
#   final_answer(key_differences)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer:
# Key Differences between Python List and Tuple:
# 1. **Mutability**: Lists are mutable (can be modified after creation), while tuples are immutable (cannot be
# modified after creation).
# 2. **Performance**: Tuples can be slightly faster than lists due to their immutability.
# 3. **Memory Usage**: Tuples can use less memory compared to lists.
# 4. **Usage**: Lists are generally used for collections of homogeneous elements, while tuples can be used for
# heterogeneous elements.
# 5. **Methods**: Lists have more built-in methods that allow modifications like append(), remove(), insert(), etc.,
# whereas tuples have fewer methods (count(), index()).
# [Step 2: Duration 9.33 seconds| Input tokens: 5,150 | Output tokens: 285]
# Key Differences between Python List and Tuple:
# 1. **Mutability**: Lists are mutable (can be modified after creation), while tuples are immutable (cannot be modified after creation).
# 2. **Performance**: Tuples can be slightly faster than lists due to their immutability.
# 3. **Memory Usage**: Tuples can use less memory compared to lists.
# 4. **Usage**: Lists are generally used for collections of homogeneous elements, while tuples can be used for heterogeneous elements.
# 5. **Methods**: Lists have more built-in methods that allow modifications like append(), remove(), insert(), etc., whereas tuples have fewer methods (count(), index()).

# %% [markdown]
# ### 🤔 Exercise 1 Challenge
# Try asking the agent to explain different programming concepts and evaluate its responses. How well does it handle:
# 1. Basic syntax questions
# 2. Language-specific features
# 3. Code examples

# %% [markdown]
# ## 🐕 Exercise 2: Agent with Custom Functions
#
# Now let's create an agent that can perform specific tasks using custom functions. We'll implement a simple calculator tool.

# %%
from smolagents import CodeAgent, tool
from typing import Union


@tool
def calculate(operation: str, numbers: object) -> float:
    """Performs basic mathematical operations on a list of numbers.

    Args:
        operation: One of 'sum', 'average', 'multiply', 'min', 'max'
        numbers: List of numbers to operate on

    Returns:
        float: Result of the operation
    """
    if operation == "sum":
        return sum(numbers)
    elif operation == "average":
        return sum(numbers) / len(numbers)
    elif operation == "multiply":
        result = 1
        for n in numbers:
            result *= n
        return result
    elif operation == "min":
        return min(numbers)
    elif operation == "max":
        return max(numbers)
    else:
        raise ValueError(f"Unknown operation: {operation}")


# Create agent with custom tool
math_agent = CodeAgent(tools=[calculate], model=HfApiModel())

# Test the agent
response = math_agent.run("What is the average of 10, 15, 20, 25, and 30?")
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the average of 10, 15, 20, 25, and 30?                                                                  │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   numbers = [10, 15, 20, 25, 30]
#   average_result = calculate(operation="average", numbers=numbers)
#   final_answer(average_result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: 20.0
# [Step 1: Duration 5.04 seconds| Input tokens: 2,073 | Output tokens: 96]
# 20.0

# %% [markdown]
# ### 🤔 Exercise 2 Challenge
# 1. Add more mathematical operations to the calculator tool
# 2. Create a new custom tool (e.g., for string manipulation or date calculations)
# 3. Combine multiple custom tools in one agent

# %%
from smolagents import CodeAgent, tool
from typing import Union


@tool
def lower_case(text :str) -> str:
    """Converts a string to lower case.

    Args:
        text: The input string to convert

    Returns:
        str: The lower case version of the input string
    """
    return text.lower()

@tool
def calculate(operation: str, numbers: object) -> float:
    """Performs basic mathematical operations on a list of numbers.

    Args:
        operation: One of 'sum', 'average', 'multiply', 'min', 'max'
        numbers: List of numbers to operate on

    Returns:
        float: Result of the operation
    """
    if operation == "sum":
        return sum(numbers)
    elif operation == "average":
        return sum(numbers) / len(numbers)
    elif operation == "multiply":
        result = 1
        for n in numbers:
            result *= n
        return result
    elif operation == "min":
        return min(numbers)
    elif operation == "max":
        return max(numbers)
    elif operation == "difference":
        return max(numbers) - min(numbers)
    else:
        raise ValueError(f"Unknown operation: {operation}")


# Create agent with custom tool
math_agent = CodeAgent(tools=[calculate, lower_case], model=HfApiModel())

# Test the agent
response = math_agent.run("What is the biggest difference of 10, 15, 20, 25, and 30?")
print(response)

response = math_agent.run("What is the BIGGEST difference of 10, 15, 20, 25, and 30? Write the answer in lower case words")
print(response)
# Out:
# /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/models.py:1372: FutureWarning: HfApiModel was renamed to InferenceClientModel in version 1.14.0 and will be removed in 1.17.0.
#   warnings.warn(
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the biggest difference of 10, 15, 20, 25, and 30?                                                       │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   numbers = [10, 15, 20, 25, 30]
#   max_value = max(numbers)
#   min_value = min(numbers)
#   biggest_difference = max_value - min_value
#   final_answer(biggest_difference)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: 20
# [Step 1: Duration 4.88 seconds| Input tokens: 2,108 | Output tokens: 108]
# 20
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the BIGGEST difference of 10, 15, 20, 25, and 30? Write the answer in lower case words                  │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   numbers = [10, 15, 20, 25, 30]
#   max_value = max(numbers)
#   min_value = min(numbers)
#   biggest_difference = calculate(operation='max', numbers=[max_value - min_value])
#   biggest_difference_lower = lower_case(str(biggest_difference))
#   final_answer(biggest_difference_lower)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: 20
# [Step 1: Duration 6.34 seconds| Input tokens: 2,116 | Output tokens: 140]
# 20

# %% [markdown]
# ## 🦁 Exercise 3: Advanced Retrieval Agent
#
# Finally, let's build a more sophisticated agent that combines web search with memory to maintain context across conversations.

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, Tool, BM25Retriever

class RetrieverTool(Tool):
    name = "retriever"
    description = "Uses semantic search to retrieve the parts of transformers documentation that could be most relevant to answer your query."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be semantically close to your target documents. Use the affirmative form rather than a question.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=10
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved documents:\n" + "".join(
            [
                f"\n\n===== Document {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )



search_tool = DuckDuckGoSearchTool()

# Initialize the model
model = HfApiModel()
retriever_tool = RetrieverTool(docs_processed)

# Initialize the agent with memory
research_agent = CodeAgent(tools=[search_tool, retriever_tool],
                           model=model)  # TODO: Define the agent

# Test with a multi-turn conversation
questions = [
    "What are the main types of machine learning?",
    "Can you explain supervised learning in more detail?",
    "What are some popular algorithms for this type?",
]

responses = []
for question in questions:
    response = research_agent.run(question)
    responses.append(response)
    print(f"Q: {question}\nA: {response}\n")

# TODO: Test the agent
# Out:
# /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/models.py:1372: FutureWarning: HfApiModel was renamed to InferenceClientModel in version 1.14.0 and will be removed in 1.17.0.
#   warnings.warn(
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What are the main types of machine learning?                                                                    │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_result = web_search(query="main types of machine learning")
#   print(search_result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Types of Machine Learning - GeeksforGeeks](https://www.geeksforgeeks.org/types-of-machine-learning/)
# Machine learning helps to predict massive amounts of data. It helps to deliver fast and accurate results to get
# profitable opportunities. Types of Machine Learning. There are several types of machine learning, each with special
# characteristics and applications. Some of the main types of machine learning algorithms are as follows:
#
# [Types of Machine Learning | IBM](https://www.ibm.com/think/topics/machine-learning-types)
# Explore the five major machine learning types, including their unique benefits and capabilities, that teams can
# leverage for different tasks. ... Supervised machine learning is a type of machine learning where the model is
# trained on a labeled dataset (i.e., the target or outcome variable is known). For instance, if data scientists were
# ...
#
# [3 Types of Machine Learning You Should Know -
# Coursera](https://www.coursera.org/articles/types-of-machine-learning)
# 3 types of machine learning Machine learning uses large volumes of data to learn, make predictions, find patterns,
# or classify information. While there are several types of machine learning, three of the most common kinds include
# supervised learning, unsupervised learning, and reinforcement learning. Here's what you need to know about each
# one. 1.
#
# [Types of Machine Learning: A Detailed Guide to the 4 Main Types -
# Emeritus](https://emeritus.org/blog/ai-and-ml-types-of-machine-learning/)
# Unsupervised learning is one of the four main types of machine learning techniques. It utilizes unlabeled and
# unclassified datasets to make predictions without human intervention. This method is useful for categorizing or
# grouping unsorted data based on similarities and differences, as well as discovering hidden patterns and trends in
# the input data.
#
# [14 Different Types of Learning in Machine
# Learning](https://machinelearningmastery.com/types-of-learning-in-machine-learning/)
# First, we will take a closer look at three main types of learning problems in machine learning: supervised,
# unsupervised, and reinforcement learning. 1. Supervised Learning. Supervised learning describes a class of problem
# that involves using a model to learn a mapping between input examples and the target variable.
#
# [Exploring the 4 Main Types of Machine Learning - Alert Hub](https://alerts2.uh.edu/types-of-machine-learning)
# Discover the essential types of machine learning, including supervised, unsupervised, semi-supervised, and
# reinforcement learning. Explore how these algorithms process data, make predictions, and improve decision-making in
# various applications. Learn the differences, use cases, and benefits of each type to enhance your understanding of
# machine learning techniques and their real-world applications.
#
# [Different Types of Machine Learning: Explained in
# Detail](https://www.theknowledgeacademy.com/blog/types-of-machine-learning/)
# The market is expected to reach $26.03 billion in 2023 and reach $225.91 billion by 2030. These statistics are a
# true testament that understanding the Types of Machine Learning is crucial. Different Types of Machine Learning
# have specific uses and are important in developing intelligent systems in various industries.
#
# [4 Types of Machine Learning - Built In](https://builtin.com/machine-learning/types-of-machine-learning)
# Supervised learning, like each of these machine learning types, serves as an umbrella for specific algorithms and
# statistical methods, including the ones below. Classification . Used to further categorize data, classification
# algorithms are a great tool to sort, and even hide, that data. (If you use a Gmail or any large email client, you
# may ...
#
# [5 types of machine learning (Updated 2025)](https://lumenalta.com/insights/5-types-of-machine-learning)
# The 5 types of machine learning are supervised, unsupervised, semi-supervised, self-supervised, and reinforcement
# learning. Each serves different tasks. ... The two main techniques in unsupervised learning are clustering, which
# groups data points with similar characteristics, and association, which identifies relationships between variables.
# ...
#
# [4 Types of Learning in Machine Learning Explained -
# TechTarget](https://www.techtarget.com/searchEnterpriseAI/tip/Types-of-learning-in-machine-learning-explained)
# The four main types of machine learning and their most common algorithms. Here's a deeper look at the four main
# types of machine learning models. 1. Supervised learning model. Supervised learning models work with data that has
# been previously labeled. The downside is that someone or some process needs to apply these labels.
#
# Out: None
# [Step 1: Duration 5.45 seconds| Input tokens: 2,046 | Output tokens: 74]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   main_types_of_ml = {
#       "Supervised Learning": "Uses labeled data to train models to predict outcomes.",
#       "Unsupervised Learning": "Uses unlabeled data to find patterns and classify information.",
#       "Reinforcement Learning": "Trains models to make a series of decisions by rewarding desired outcomes and
#   penalizing undesired ones.",
#       "Semi-Supervised Learning": "Uses a combination of labeled and unlabeled data for training.",
#       "Self-Supervised Learning": "Similar to unsupervised learning, but the model learns from task-specific
#   objectives generated from the data itself."
#   }
#
#   print(main_types_of_ml)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# {'Supervised Learning': 'Uses labeled data to train models to predict outcomes.', 'Unsupervised Learning': 'Uses
# unlabeled data to find patterns and classify information.', 'Reinforcement Learning': 'Trains models to make a
# series of decisions by rewarding desired outcomes and penalizing undesired ones.', 'Semi-Supervised Learning':
# 'Uses a combination of labeled and unlabeled data for training.', 'Self-Supervised Learning': 'Similar to
# unsupervised learning, but the model learns from task-specific objectives generated from the data itself.'}
#
# Out: None
# [Step 2: Duration 10.19 seconds| Input tokens: 5,164 | Output tokens: 284]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   main_types_of_ml = [
#       "Supervised Learning",
#       "Unsupervised Learning",
#       "Reinforcement Learning",
#       "Semi-Supervised Learning"
#   ]
#
#   answer = "The main types of machine learning are: " + ", ".join(main_types_of_ml) + "."
#   final_answer(answer)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: The main types of machine learning are: Supervised Learning, Unsupervised Learning,
# Reinforcement Learning, Semi-Supervised Learning.
# [Step 3: Duration 9.33 seconds| Input tokens: 8,803 | Output tokens: 394]
# Q: What are the main types of machine learning?
# A: The main types of machine learning are: Supervised Learning, Unsupervised Learning, Reinforcement Learning, Semi-Supervised Learning.
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Can you explain supervised learning in more detail?                                                             │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_result = web_search(query="supervised learning")
#   print(search_result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Supervised and Unsupervised learning -
# GeeksforGeeks](https://www.geeksforgeeks.org/supervised-unsupervised-learning/)
# Supervised and unsupervised learning are two main types of machine learning.In supervised learning, the model is
# trained with labeled data where each input has a corresponding output. On the other hand, unsupervised learning
# involves training the model with unlabeled data which helps to uncover patterns, structures or relationships within
# the data without predefined outputs.
#
# [What Is Supervised Learning? - IBM](https://www.ibm.com/think/topics/supervised-learning)
# Supervised learning is a machine learning technique that uses human-labeled input and output datasets to train
# artificial intelligence models. The trained model learns the underlying relationships between inputs and outputs,
# enabling it to predict correct outputs based on new, unlabeled real-world input data.
#
# [Supervised learning - Wikipedia](https://en.wikipedia.org/wiki/Supervised_learning)
# Learn about supervised learning, a paradigm of machine learning where a model is trained using labeled data and
# desired output values. Find out the steps, issues, and algorithms involved in supervised learning.
#
# [Supervised Learning | Machine Learning | Google for
# Developers](https://developers.google.com/machine-learning/intro-to-ml/supervised)
# Learn the core concepts of supervised learning, such as data, model, training, evaluation, and inference. See
# examples of how to apply supervised learning to various scenarios, such as identifying spam or predicting
# precipitation.
#
# [What is Supervised Learning? | Definition from
# TechTarget](https://www.techtarget.com/searchenterpriseai/definition/supervised-learning)
# Supervised learning is a subcategory of machine learning and artificial intelligence where a computer algorithm is
# trained on input data that has been labeled for a particular output. The model is trained until it can detect the
# underlying patterns and relationships between the input data and the output labels, enabling it to yield accurate
# labeling results when presented with never-before ...
#
# [What Is Supervised Learning? (Definition, Examples) - Built
# In](https://builtin.com/machine-learning/supervised-learning)
# Supervised learning is a machine learning approach that uses labeled data sets to train algorithms to classify data
# and predict outcomes. Learn about the types of supervised learning, such as regression, classification, naive
# Bayes, decision trees and neural networks, and see examples of how they are used.
#
# [Supervised Learning - Statistics by Jim](https://statisticsbyjim.com/glossary/supervised-learning/)
# Supervised learning is a type of machine learning where models are trained using labeled data. That is, data where
# the correct output is already known for each observation. The model learns the relationship between the inputs
# (also called features or predictors ) and the known outputs (called labels or target values), so that it can
# accurately predict the output for new, unseen data.
#
# [Supervised Learning Definition -
# DeepAI](https://deepai.org/machine-learning-glossary-and-terms/supervised-learning)
# Supervised learning is a method where an algorithm learns from labeled data to make predictions or decisions. Learn
# about the types, algorithms, advantages, challenges, and applications of supervised learning in machine learning
# and artificial intelligence.
#
# [What is Supervised Learning? - Definition and Explaination - C3
# AI](https://c3.ai/introduction-what-is-machine-learning/supervised-learning/)
# Supervised learning is a machine learning technique that uses labeled data to train a model to predict outputs
# based on inputs. Learn about the two main types of supervised learning (classification and regression), how models
# are trained and evaluated, and see examples of applications.
#
# [What is Supervised Learning? - Techopedia](https://www.techopedia.com/definition/supervised-learning)
# Supervised learning is a type of machine learning that uses labeled data sets to train predictive AI models. Learn
# how it works, its advantages and disadvantages, and its applications in various AI fields.
#
# Out: None
# [Step 1: Duration 4.39 seconds| Input tokens: 2,046 | Output tokens: 63]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   supervised_learning_explanation = (
#       "Supervised learning is a machine learning technique where a model is trained using labeled data, "
#       "meaning that each input data point is paired with the correct output. The main goal is for the model to "
#       "learn the underlying relationship between inputs and outputs so that it can make accurate predictions "
#       "on new, unseen data. This approach is widely used in various applications, including classification "
#       "(predicting discrete labels) and regression (predicting continuous values). Common algorithms used in "
#       "supervised learning include decision trees, support vector machines, random forests, and neural networks.
#   "
#       "The process involves training the model on the labeled dataset and then evaluating its performance using a
#   separate set "
#       "of test data to ensure accurate predictions."
#   )
#
#   final_answer(supervised_learning_explanation)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Supervised learning is a machine learning technique where a model is trained using labeled
# data, meaning that each input data point is paired with the correct output. The main goal is for the model to learn
# the underlying relationship between inputs and outputs so that it can make accurate predictions on new, unseen
# data. This approach is widely used in various applications, including classification (predicting discrete labels)
# and regression (predicting continuous values). Common algorithms used in supervised learning include decision
# trees, support vector machines, random forests, and neural networks. The process involves training the model on the
# labeled dataset and then evaluating its performance using a separate set of test data to ensure accurate
# predictions.
# [Step 2: Duration 13.32 seconds| Input tokens: 5,025 | Output tokens: 272]
# Q: Can you explain supervised learning in more detail?
# A: Supervised learning is a machine learning technique where a model is trained using labeled data, meaning that each input data point is paired with the correct output. The main goal is for the model to learn the underlying relationship between inputs and outputs so that it can make accurate predictions on new, unseen data. This approach is widely used in various applications, including classification (predicting discrete labels) and regression (predicting continuous values). Common algorithms used in supervised learning include decision trees, support vector machines, random forests, and neural networks. The process involves training the model on the labeled dataset and then evaluating its performance using a separate set of test data to ensure accurate predictions.
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What are some popular algorithms for this type?                                                                 │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   algorithms_info = web_search("popular algorithms")
#   print(algorithms_info)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Top 25 Algorithms Every Programmer Should
# Know](https://www.techiedelight.com/top-25-algorithms-every-programmer-should-know/)
# Learn the most common and useful algorithms for various problems in computer science, such as sorting, searching,
# graph, and string algorithms. See examples, pseudocode, and complexity analysis for each algorithm.
#
# [List of algorithms - Wikipedia](https://en.wikipedia.org/wiki/List_of_algorithms)
# The following is a list of well-known algorithms along with one-line descriptions for each. Automated planning
# Combinatorial algorithms. General combinatorial algorithms ... a popular algorithm for k-means clustering; OPTICS:
# a density based clustering algorithm with a visual evaluation method; Single-linkage clustering: a simple
# agglomerative ...
#
# [Top 10 Algorithms and Data Structures for Competitive
# Programming](https://www.geeksforgeeks.org/top-algorithms-and-data-structures-for-competitive-programming/)
# In this post, we will discuss Important top 10 algorithms and data structures for competitive coding. Topics :
# Graph algorithms; Dynamic programming; Searching and Sorting: Number theory and Other Mathematical; Geometrical and
# Network Flow Algorithms; Data Structures; The links below cover most important algorithms and data structure topics
# ...
#
# [Top 11 Algorithms Every Developer Should Know in
# 2025](https://www.index.dev/blog/must-know-algorithms-for-developers)
# Discover the top 11 essential algorithms for software developers in 2025, including Sorting, Machine Learning, and
# more. Learn how they work with code examples and why they're important. Roles. ... Decision trees and KNN are
# popular for tasks like spam detection or customer segmentation. Importance in 2025. In 2025, machine learning
# algorithms ...
#
# [The Essential 25: Algorithms Every Programmer Should
# Master](https://medium.com/@johnadjanohoun/the-essential-25-algorithms-every-programmer-should-master-82c5514163ff)
# Whether you're sorting data, searching through databases, or optimizing code performance, these algorithms are the
# keys to efficient and effective programming. Follow Written by Jean claude ...
#
# [Top 10 Algorithms Every Programmer Should Know -
# MYCPLUS](https://www.mycplus.com/featured-articles/top-10-algorithms-every-programmer-should-know/)
# Sorting algorithms are essential for organizing data in a specific order, typically in ascending or descending.
# Quick Sort and Merge Sort are popular for their efficiency, while simpler algorithms like Bubble Sort provide a
# foundational understanding of sorting techniques. Examples: Quick Sort, Merge Sort, Bubble Sort
#
# [10 Famous Algorithms Every Programmer Should
# Know](https://technotes.blog/2023/01/15/10-famous-algorithms-every-programmer-should-know/)
# Sorting algorithms: Sorting algorithms are used to arrange data in a specific order. Quicksort, merge sort, and
# heap sort are some of the most popular and efficient algorithms for sorting data. Quicksort is a divide-and-conquer
# algorithm that works by partitioning the data into smaller sub-arrays and then recursively sorting them.
#
# [Top 25 Algorithms Every Programmer Should Know - GitHub](https://github.com/tiagoavila/top-25-algorithms)
# Lee Algorithm. Lee Algorithm is a pathfinding algorithm used for maze solving and image analysis. It explores the
# maze in a wave-like fashion. Flood Fill Algorithm. Flood Fill is a technique for filling connected regions in an
# image with a specific color. It's commonly used in graphical applications. Floyd's Cycle Detection Algorithm
#
# [Decoding the Algorithm: The 10 Most Used Algorithms -
# Bismart](https://blog.bismart.com/en/10-more-used-algorithms)
# A greedy algorithm is an approach to algorithm design that makes local decisions at each step in the hope of
# arriving at a globally optimal solution. In other words, at each step, the algorithm selects the option that
# appears to be the best at the time, without considering the long-term consequences.The idea is to make decisions
# that appear to be the most beneficial at the present moment ...
#
# [Top 15 Algorithms Every Software Engineer Must Know -
# SoftwareDominos](https://softwaredominos.com/home/software-engineering-and-computer-science/top-15-algorithms-every
# -software-engineer-must-know/)
# Problem Description—Sorting algorithms rearrange the elements of an array of N random numbers in ascending order.
# Several algorithms compete for the lowest runtime and memory usage complexity. 4.1 Insertion Sort. Insertion sort
# is an intuitive yet costly sorting algorithm, and it works by running up to N passes over the entire array.
#
# Out: None
# [Step 1: Duration 6.49 seconds| Input tokens: 2,046 | Output tokens: 118]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extract algorithms from the search results
#   search_results = """
#   ## Search Results
#
#   [Top 25 Algorithms Every Programmer Should
#   Know](https://www.techiedelight.com/top-25-algorithms-every-programmer-should-know/)
#   Learn the most common and useful algorithms for various problems in computer science, such as sorting,
#   searching, graph, and string algorithms. See examples, pseudocode, and complexity analysis for each algorithm.
#
#   [List of algorithms - Wikipedia](https://en.wikipedia.org/wiki/List_of_algorithms)
#   The following is a list of well-known algorithms along with one-line descriptions for each. Automated planning
#   Combinatorial algorithms. General combinatorial algorithms ... a popular algorithm for k-means clustering;
#   OPTICS: a density based clustering algorithm with a visual evaluation method; Single-linkage clustering: a
#   simple agglomerative ...
#
#   [Top 10 Algorithms and Data Structures for Competitive
#   Programming](https://www.geeksforgeeks.org/top-algorithms-and-data-structures-for-competitive-programming/)
#   In this post, we will discuss Important top 10 algorithms and data structures for competitive coding. Topics :
#   Graph algorithms; Dynamic programming; Searching and Sorting: Number theory and Other Mathematical; Geometrical
#   and Network Flow Algorithms; Data Structures; The links below cover most important algorithms and data
#   structure topics ...
#
#   [Top 11 Algorithms Every Developer Should Know in
#   2025](https://www.index.dev/blog/must-know-algorithms-for-developers)
#   Discover the top 11 essential algorithms for software developers in 2025, including Sorting, Machine Learning,
#   and more. Learn how they work with code examples and why they're important. Roles. ... Decision trees and KNN
#   are popular for tasks like spam detection or customer segmentation. Importance in 2025. In 2025, machine
#   learning algorithms ...
#
#   [The Essential 25: Algorithms Every Programmer Should
#   Master](https://medium.com/@johnadjanohoun/the-essential-25-algorithms-every-programmer-should-master-82c551416
#   3ff)
#   Whether you're sorting data, searching through databases, or optimizing code performance, these algorithms are
#   the keys to efficient and effective programming. Follow Written by Jean claude ...
#
#   [Top 10 Algorithms Every Programmer Should Know -
#   MYCPLUS](https://www.mycplus.com/featured-articles/top-10-algorithms-every-programmer-should-know/)
#   Sorting algorithms are essential for organizing data in a specific order, typically in ascending or descending.
#   Quick Sort and Merge Sort are popular for their efficiency, while simpler algorithms like Bubble Sort provide a
#   foundational understanding of sorting techniques. Examples: Quick Sort, Merge Sort, Bubble Sort
#
#   [10 Famous Algorithms Every Programmer Should
#   Know](https://technotes.blog/2023/01/15/10-famous-algorithms-every-programmer-should-know/)
#   Sorting algorithms: Sorting algorithms are used to arrange data in a specific order. Quicksort, merge sort, and
#   heap sort are some of the most popular and efficient algorithms for sorting data. Quicksort is a
#   divide-and-conquer algorithm that works by partitioning the data into smaller sub-arrays and then recursively
#   sorting them.
#
#   [Top 25 Algorithms Every Programmer Should Know - GitHub](https://github.com/tiagoavila/top-25-algorithms)
#   Lee Algorithm. Lee Algorithm is a pathfinding algorithm used for maze solving and image analysis. It explores
#   the maze in a wave-like fashion. Flood Fill Algorithm. Flood Fill is a technique for filling connected regions
#   in an image with a specific color. It's commonly used in graphical applications. Floyd's Cycle Detection
#   Algorithm
#
#   [Decoding the Algorithm: The 10 Most Used Algorithms -
#   Bismart](https://blog.bismart.com/en/10-more-used-algorithms)
#   A greedy algorithm is an approach to algorithm design that makes local decisions at each step in the hope of
#   arriving at a globally optimal solution. In other words, at each step, the algorithm selects the option that
#   appears to be the best at the time, without considering the long-term consequences.The idea is to make
#   decisions that appear to be the most beneficial at the present moment ...
#
#   [Top 15 Algorithms Every Software Engineer Must Know -
#   SoftwareDominos](https://softwaredominos.com/home/software-engineering-and-computer-science/top-15-algorithms-e
#   very-software-engineer-must-know/)
#   Problem Description—Sorting algorithms rearrange the elements of an array of N random numbers in ascending
#   order. Several algorithms compete for the lowest runtime and memory usage complexity. 4.1 Insertion Sort.
#   Insertion sort is an intuitive yet costly sorting algorithm, and it works by running up to N passes over the
#   entire array.
#   """
#
#   # Split the search results into individual items
#   items = search_results.split("## Search Results")[1].strip().split("\n\n")
#
#   # Initialize lists to hold different types of algorithms
#   sorting_algorithms = []
#   searching_algorithms = []
#   graph_algorithms = []
#   dynamic_programming_algorithms = []
#   other_algorithms = []
#
#   # Loop through each item, find the algorithms, and add them to the appropriate list
#   for item in items:
#       if "Sorting" in item:
#           sorting_algorithms += re.findall(r'\b(?:Quick Sort|Merge Sort|Bubble Sort|Heap Sort|Insertion Sort)\b',
#   item, re.IGNORECASE)
#       elif "Searching" in item:
#           searching_algorithms += re.findall(r'\b(?:Binary Search|Linear Search|Depth First Search|Breadth First
#   Search)\b', item, re.IGNORECASE)
#       elif "Graph" in item:
#           graph_algorithms += re.findall(r'\b(?:Lee Algorithm|Floyd\'s Cycle Detection Algorithm|Dijkstra\'s
#   Algorithm|DFS|BFS)\b', item, re.IGNORECASE)
#       elif "Dynamic Programming" in item:
#           dynamic_programming_algorithms += re.findall(r'\b(?:Knapsack Problem|Fibonacci Sequence|Shortest
#   Path|Matrix Chain Multiplication)\b', item, re.IGNORECASE)
#       else:
#           other_algorithms += re.findall(r'\b(?:K-means Clustering|OPTICS|Single-linkage clustering|KNN|Decision
#   Trees|Greedy Algorithm)\b', item, re.IGNORECASE)
#
#   # Remove duplicates by converting to sets and then back to lists
#   sorting_algorithms = list(set(sorting_algorithms))
#   searching_algorithms = list(set(searching_algorithms))
#   graph_algorithms = list(set(graph_algorithms))
#   dynamic_programming_algorithms = list(set(dynamic_programming_algorithms))
#   other_algorithms = list(set(other_algorithms))
#
#   # Compile the results
#   popular_algorithms = {
#       "Sorting Algorithms": sorting_algorithms,
#       "Searching Algorithms": searching_algorithms,
#       "Graph Algorithms": graph_algorithms,
#       "Dynamic Programming Algorithms": dynamic_programming_algorithms,
#       "Other Algorithms": other_algorithms
#   }
#
#   print(popular_algorithms)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'for item in items:
#     if "Sorting" in item:
#         sorting_algorithms += re.findall(r'\b(?:Quick Sort|Merge Sort|Bubble Sort|Heap Sort|Insertion Sort)\b',
# item, re.IGNORECASE)
#     elif "Searching" in item:
#         searching_algorithms += re.findall(r'\b(?:Binary Search|Linear Search|Depth First Search|Breadth First
# Search)\b', item, re.IGNORECASE)
#     elif "Graph" in item:
#         graph_algorithms += re.findall(r'\b(?:Lee Algorithm|Floyd\'s Cycle Detection Algorithm|Dijkstra\'s
# Algorithm|DFS|BFS)\b', item, re.IGNORECASE)
#     elif "Dynamic Programming" in item:
#         dynamic_programming_algorithms += re.findall(r'\b(?:Knapsack Problem|Fibonacci Sequence|Shortest
# Path|Matrix Chain Multiplication)\b', item, re.IGNORECASE)
#     else:
#         other_algorithms += re.findall(r'\b(?:K-means Clustering|OPTICS|Single-linkage clustering|KNN|Decision
# Trees|Greedy Algorithm)\b', item, re.IGNORECASE)' due to: InterpreterError: The variable `re` is not defined.
# [Step 2: Duration 68.26 seconds| Input tokens: 5,245 | Output tokens: 1,609]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# 402 Client Error: Payment Required for url:
# https://router.huggingface.co/hf-inference/models/Qwen/Qwen2.5-Coder-32B-Instruct/v1/chat/completions (Request ID:
# Root=1-683b8f1d-18f40d3f378c73132d49926f;6f72dd5c-563b-4017-9003-cd8548d91870)
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly
# included credits.
# [Step 3: Duration 0.20 seconds]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/hf-inference/models/Qwen/Qwen2.5-Coder-32B-Instruct/v1/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/agents.py:1496, in CodeAgent._step_stream(self, memory_step)
#    1495 else:
# -> 1496     chat_message: ChatMessage = self.model.generate(
#    1497         input_messages,
#    1498         stop_sequences=["<end_code>", "Observation:", "Calling tools:"],
#    1499         **additional_args,
#    1500     )
#    1501     memory_step.model_output_message = chat_message
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/models.py:1309, in InferenceClientModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1300 completion_kwargs = self._prepare_completion_kwargs(
#    1301     messages=messages,
#    1302     stop_sequences=stop_sequences,
#    (...)
#    1307     **kwargs,
#    1308 )
# -> 1309 response = self.client.chat_completion(**completion_kwargs)
#    1311 self._last_input_token_count = response.usage.prompt_tokens
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:924, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     917 request_parameters = provider_helper.prepare_request(
#     918     inputs=messages,
#     919     parameters=parameters,
#    (...)
#     922     api_key=self.token,
#     923 )
# --> 924 data = self._inner_post(request_parameters, stream=stream)
#     926 if stream:
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:280, in InferenceClient._inner_post(self, request_parameters, stream)
#     279 try:
# --> 280     hf_raise_for_status(response)
#     281     return response.iter_lines() if stream else response.content
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/hf-inference/models/Qwen/Qwen2.5-Coder-32B-Instruct/v1/chat/completions (Request ID: Root=1-683b8f1d-18f40d3f378c73132d49926f;6f72dd5c-563b-4017-9003-cd8548d91870)
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[9], line 21
#      19 responses = []
#      20 for question in questions:
# ---> 21     response = research_agent.run(question)
#      22     responses.append(response)
#      23     print(f"Q: {question}\nA: {response}\n")
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/agents.py:399, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps)
#     396 run_start_time = time.time()
#     397 # Outputs are returned only at the end. We only look at the last step.
# --> 399 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     400 assert isinstance(steps[-1], FinalAnswerStep)
#     401 output = steps[-1].output
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/agents.py:478, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     475     final_answer = el
#     476 except AgentGenerationError as e:
#     477     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 478     raise e
#     479 except AgentError as e:
#     480     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     481     action_step.error = e
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/agents.py:473, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     467 action_step = ActionStep(
#     468     step_number=self.step_number,
#     469     timing=Timing(start_time=action_step_start_time),
#     470     observations_images=images,
#     471 )
#     472 try:
# --> 473     for el in self._execute_step(action_step):
#     474         yield el
#     475     final_answer = el
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/agents.py:495, in MultiStepAgent._execute_step(self, memory_step)
#     493 def _execute_step(self, memory_step: ActionStep) -> Generator[ChatMessageStreamDelta | FinalOutput]:
#     494     self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
# --> 495     for el in self._step_stream(memory_step):
#     496         final_answer = el
#     497         if isinstance(el, ChatMessageStreamDelta):
#
# File /workspaces/smol-course/.venv/lib/python3.11/site-packages/smolagents/agents.py:1518, in CodeAgent._step_stream(self, memory_step)
#    1516     memory_step.model_output = output_text
#    1517 except Exception as e:
# -> 1518     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1520 ### Parse output ###
#    1521 try:
#
# AgentGenerationError: Error in generating model output:
# 402 Client Error: Payment Required for url: https://router.huggingface.co/hf-inference/models/Qwen/Qwen2.5-Coder-32B-Instruct/v1/chat/completions (Request ID: Root=1-683b8f1d-18f40d3f378c73132d49926f;6f72dd5c-563b-4017-9003-cd8548d91870)
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.

# %% [markdown]
# ### 🤔 Exercise 3 Challenge
# 1. Test how well the agent maintains context across different topics
# 2. Implement a custom knowledge base tool (as shown in the retrieval_agents.md example)
# 3. Create a hybrid agent that combines code understanding with research capabilities
